# %%
import pandas as pd

# %%
CronicIllDS = pd.read_csv(r"C:\Users\brian\Desktop\Springboard\Capstone Two - Project Ideas\Chronic Illness_data_set\export.csv", low_memory=False)

# %%
CronicIllDS.head()
# Out:
#                             user_id   age     sex country checkin_date  \
# 0  QEVuQwEABlEzkh7fsBBjEe26RyIVcg==   NaN     NaN     NaN   2015-11-26
# 1  QEVuQwEAWRNGnuTRqXG2996KSkTIEw==  32.0    male      US   2015-11-26
# 2  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 3  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
# 4  QEVuQwEA+WkNxtp/qkHvN2YmTBBDqg==   2.0  female      CA   2017-04-28
#
#   trackable_id trackable_type  \
# 0         1069      Condition
# 1         1069      Condition
# 2         3168      Condition
# 3         3169      Condition
# 4         3170      Condition
#
#                                       trackable_name trackable_value
# 0                                 Ulcerative colitis               0
# 1                                 Ulcerative colitis               0
# 2  pain in left upper arm felt like i was getting...               4
# 3                            hip pain when gettin up               3
# ...

# %%
CronicIllDS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7976223 entries, 0 to 7976222
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   user_id          object
#  1   age              float64
#  2   sex              object
#  3   country          object
#  4   checkin_date     object
#  5   trackable_id     object
#  6   trackable_type   object
#  7   trackable_name   object
#  8   trackable_value  object
# dtypes: float64(1), object(8)
# memory usage: 547.7+ MB

# %%
missing = pd.concat([CronicIllDS.isnull().sum(), 100 * CronicIllDS.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#                   count          %
# user_id               0   0.000000
# checkin_date          0   0.000000
# trackable_id          0   0.000000
# trackable_type        0   0.000000
# trackable_name        1   0.000013
# sex              132135   1.656611
# country          297985   3.735916
# age              309226   3.876847
# trackable_value  926855  11.620224

# %%
CronicIllDS['user_id'].nunique()
# Out:
# 42283

# %%
CronicIllDS.sample(n=30)
# Out:
#                                   user_id   age         sex country  \
# 384707   QEVuQwEAiExX0RQiqcR9lV+fVJ7jXw==  29.0      female      US
# 3504506  QEVuQwEAn2jQ2sk7rzjk9/NCAv+KVg==  27.0      female      US
# 6758071  QEVuQwEAtKWBXg4nrPlc+AmcLV8+sA==  33.0      female      CA
# 3424367  QEVuQwEASxfuKWMOFMTcc31FQF/RzQ==  37.0       other      GB
# 1897349  QEVuQwEAyM8LgE0QDRvdvqHKKTCm3Q==  35.0      female      CA
# 2753712  QEVuQwEA6NY56Md0wTBv9c6bbbTsUA==  35.0      female      US
# 949936   QEVuQwEAWz7pDjtgiS8y2+BHpLdV5g==  30.0      female      US
# 4001558  QEVuQwEA4/v7/QC66SzB/Tr30qzJlg==  58.0      female      AU
# 3674685  QEVuQwEAJR3/auGHjxC15yoo730oLg==  34.0      female      US
# 1638755  QEVuQwEApD0iDTY+CcoCWqUVqHZVzg==  49.0      female      US
# 7880646  QEVuQwEAW5AmGeLd/xLLC0is2ZkRQQ==  50.0      female      US
# 1371147  QEVuQwEAD6M/HlG44vTaa2lmJNS1sQ==  61.0      female      US
# 6444504  QEVuQwEA7tUb37v0MUSih8m+alXLjA==  19.0  doesnt_say      CA
# ...
